# %% [markdown]
# EN ESTA MEMORIA SE EXPLICAN LOS PASOS RESUMIDOS DEL PROYECTO:
#
# -IMPORTACION DE MODULOS Y UTILIDADES DESDE EL DIRECTORIO RAIZ.
# -IMPORTACION CON PANDAS DE LOS DATOS.
# -VISTA PRELIMINAR DE DATOS.
# -TRANSFORMACION Y ORGANIZACION DE DATOS
# -CATEGORIZACION DE DATOS.
# -CARDINALIDADES Y TABLAS DE IMPORTANCIA EN DATOS.
# -TIPIFICACION DE DATOS EN LA TABLA DE DATOS.
# -ANALISIS UNIVARIANTE ( CODIGO Y GRAFICOS)
# -ANALISIS BIVARIANTE (COSIGO Y GRAFICOS)
# -TODOS LOS ANALIDIS INCLUYEN, FRECUENCIAS, DISTRIBUCIONES Y MEDIDAS DE POSICION.
# -TODAS LAS RELACIONES INCLUYEN TEST ESTADISTICOS, MAYORMENTE CHI CUADRADO.
# -PARA TEMRINAR ALGUNOS ANALISIS EXTRA SOBRE LAS COLUMNAS NUMERICAS.
#
# EL PROYECTO SE HA DESARROLADO EN EL NOTEBOOK CON NOMBRE : EDA_SMOKERS.
